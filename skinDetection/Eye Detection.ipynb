# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc
from scipy import ndimage

# %%
img = plt.imread('data/team1.jpg')
plt.figure(figsize = (100,10))
img = ndimage.rotate(img, 270)
plt.imshow(img)
plt.show()

# %%
import cv2
face_cascade = cv2.CascadeClassifier('C:\\Users\\Sachi\\Anaconda3\\Library\\etc/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('C:\\Users\\Sachi\\Anaconda3\\Library\\etc/haarcascades/haarcascade_eye.xml')

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
facesMap = []
for (x,y,w,h) in faces:
     cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
     roi_gray = gray[y:y+h, x:x+w]
     roi_color = img[y:y+h, x:x+w]
     eyes = eye_cascade.detectMultiScale(roi_gray)
     for (ex,ey,ew,eh) in eyes:
         cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,0,0),2)
     facesMap.append(roi_color)

# %%
#faces = face_cascade.detectMultiScale(gray, 1.3, 5)
print(len(facesMap))
# Out:
# 6

# %%
#faces
#x,y,w,h = faces[0]
#roi_color = img[y:y+h, x:x+w]
#for roi_color in facesMap:
plt.imshow(facesMap[2])

# %%
roi_gray = gray[y:y+h, x:x+w]
roi_color = img[y:y+h, x:x+w]
eyes = eye_cascade.detectMultiScale(roi_color)
ex,ey,ew,eh = eyes[0]
eye_color = img[ey:ey+eh, ex:ex+ew]
plt.imshow(eye_color)
cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
plt.imshow(roi_color)

# %%
eyes

# %%
plt.imshow(roi_color)

# %%
eyes
# Out:
# array([[ 744,  283,  428,  428],
#        [ 212,  389,  365,  365],
#        [ 769,  929,  292,  292],
#        [ 587,  870,   60,   60],
#        [1165, 1288,   65,   65],
#        [ 793, 1146,   32,   32]], dtype=int32)

# %%
cv2.rectangle(img,(ex,ey),(ex+ew,ey+eh),(255,0,0),2)
# Out:
# array([[[183, 173, 161],
#         [183, 173, 161],
#         [183, 173, 161],
#         ...,
#         [180, 171, 154],
#         [179, 170, 153],
#         [179, 170, 153]],
#
#        [[185, 175, 163],
#         [185, 175, 163],
#         [184, 174, 162],
#         ...,
#         [179, 170, 153],
#         [177, 168, 151],
#         [177, 168, 151]],
#
#        [[184, 174, 162],
#         [184, 174, 162],
#         [183, 173, 161],
#         ...,
#         [179, 170, 153],
#         [177, 168, 151],
#         [177, 168, 151]],
#
#        ...,
#
#        [[ 34,  38,  41],
#         [ 30,  34,  37],
#         [ 31,  35,  36],
#         ...,
#         [ 35,  36,  40],
#         [ 33,  34,  38],
#         [ 30,  31,  35]],
#
#        [[ 40,  44,  47],
#         [ 35,  39,  42],
#         [ 35,  39,  40],
#         ...,
#         [ 33,  34,  38],
#         [ 32,  33,  37],
#         [ 32,  33,  37]],
#
#        [[ 41,  45,  48],
#         [ 42,  46,  49],
#         [ 44,  48,  49],
# ...

# %%
plt.imshow(img)
